# %% [markdown]
# # Dataset Visualization and Slicing

# %%
import cfgrib
import xarray
import os
import plotly.express as px

# %% [markdown]
# ### Loading and Visualization South Asia ERA5 Dataset for T2M (2025 hourly)

# %%
south_asia_t2m_ds = cfgrib.open_dataset('./datasets/south-asia-2025-t2m.grib', backend_kwargs={"indexpath": "./datasets/south-asia-2025-t2m.grib.idx"})

# %%
south_asia_t2m_ds
# Out:
# <xarray.Dataset> Size: 713MB
# Dimensions:     (time: 8760, latitude: 133, longitude: 153)
# Coordinates:
#   * time        (time) datetime64[ns] 70kB 2025-01-01 ... 2025-12-31T23:00:00
#     valid_time  (time) datetime64[ns] 70kB ...
#   * latitude    (latitude) float64 1kB 38.0 37.75 37.5 37.25 ... 5.5 5.25 5.0
#   * longitude   (longitude) float64 1kB 60.0 60.25 60.5 ... 97.5 97.75 98.0
#     number      int64 8B ...
#     step        timedelta64[ns] 8B ...
#     surface     float64 8B ...
# Data variables:
#     t2m         (time, latitude, longitude) float32 713MB ...
# Attributes:
#     GRIB_edition:            1
#     GRIB_centre:             ecmf
#     GRIB_centreDescription:  European Centre for Medium-Range Weather Forecasts
#     GRIB_subCentre:          0
#     Conventions:             CF-1.7
#     institution:             European Centre for Medium-Range Weather Forecasts
#     history:                 2026-08-09T16:04 GRIB to CDM+CF via cfgrib-0.9.1...

# %%
indices = "\n".join(south_asia_t2m_ds.dims)
columns = "\n".join(south_asia_t2m_ds.data_vars)
df_size = south_asia_t2m_ds['t2m'].size

print(f"INDICES:\n{indices}\n")
print(f"COLUMNS:\n{columns}\n")
print(f"DATAPOINTS SIZE: {df_size}")
print(f"DIMENSIONS: ")
for dim in south_asia_t2m_ds.dims:
    print(f"{dim}: {south_asia_t2m_ds.sizes[dim]}")
# Out:
# INDICES:
# time
# latitude
# longitude
#
# COLUMNS:
# t2m
#
# DATAPOINTS SIZE: 178257240
# DIMENSIONS:
# time: 8760
# latitude: 133
# longitude: 153

# %% [markdown]
# ### Dropping Unnecassary Columns

# %%
south_asia_t2m_modified = south_asia_t2m_ds.drop_vars(['surface','step','valid_time', 'number'])

# %%
south_asia_t2m_modified
# Out:
# <xarray.Dataset> Size: 713MB
# Dimensions:    (time: 8760, latitude: 133, longitude: 153)
# Coordinates:
#   * time       (time) datetime64[ns] 70kB 2025-01-01 ... 2025-12-31T23:00:00
#   * latitude   (latitude) float64 1kB 38.0 37.75 37.5 37.25 ... 5.5 5.25 5.0
#   * longitude  (longitude) float64 1kB 60.0 60.25 60.5 60.75 ... 97.5 97.75 98.0
# Data variables:
#     t2m        (time, latitude, longitude) float32 713MB ...
# Attributes:
#     GRIB_edition:            1
#     GRIB_centre:             ecmf
#     GRIB_centreDescription:  European Centre for Medium-Range Weather Forecasts
#     GRIB_subCentre:          0
#     Conventions:             CF-1.7
#     institution:             European Centre for Medium-Range Weather Forecasts
#     history:                 2026-08-09T16:04 GRIB to CDM+CF via cfgrib-0.9.1...

# %% [markdown]
# ### Resampling by take 6-hour mean

# %%
south_asia_t2m_modified = south_asia_t2m_modified.resample(time='6h').mean()

# %%
indices = "\n".join(south_asia_t2m_modified.dims)
columns = "\n".join(south_asia_t2m_modified.data_vars)
df_size = south_asia_t2m_modified['t2m'].size

print(f"INDICES:\n{indices}\n")
print(f"COLUMNS:\n{columns}\n")
print(f"DATAPOINTS SIZE: {df_size}")
print(f"DIMENSIONS: ")
for dim in south_asia_t2m_modified.dims:
    print(f"{dim}: {south_asia_t2m_modified.sizes[dim]}")
# Out:
# INDICES:
# time
# latitude
# longitude
#
# COLUMNS:
# t2m
#
# DATAPOINTS SIZE: 29709540
# DIMENSIONS:
# time: 1460
# latitude: 133
# longitude: 153

# %% [markdown]
# ## Slicing out Punjab Dataset

# %%
PUNJAB_MIN_LAT = 27.5
PUNJAB_MAX_LAT = 34.0
PUNJAB_MIN_LONG = 69.0
PUNJAB_MAX_LONG = 75.5

punjab_t2m_modified = south_asia_t2m_modified.sel(latitude=slice(PUNJAB_MAX_LAT, PUNJAB_MIN_LAT), longitude=slice(PUNJAB_MIN_LONG, PUNJAB_MAX_LONG))

# %%
punjab_t2m_modified
# Out:
# <xarray.Dataset> Size: 4MB
# Dimensions:    (time: 1460, latitude: 27, longitude: 27)
# Coordinates:
#   * time       (time) datetime64[ns] 12kB 2025-01-01 ... 2025-12-31T18:00:00
#   * latitude   (latitude) float64 216B 34.0 33.75 33.5 33.25 ... 28.0 27.75 27.5
#   * longitude  (longitude) float64 216B 69.0 69.25 69.5 ... 75.0 75.25 75.5
# Data variables:
#     t2m        (time, latitude, longitude) float32 4MB 272.1 270.8 ... 285.9
# Attributes:
#     GRIB_edition:            1
#     GRIB_centre:             ecmf
#     GRIB_centreDescription:  European Centre for Medium-Range Weather Forecasts
#     GRIB_subCentre:          0
#     Conventions:             CF-1.7
#     institution:             European Centre for Medium-Range Weather Forecasts
#     history:                 2026-08-09T16:04 GRIB to CDM+CF via cfgrib-0.9.1...

# %%
indices = "\n".join(punjab_t2m_modified.dims)
columns = "\n".join(punjab_t2m_modified.data_vars)
df_size = punjab_t2m_modified['t2m'].size

print(f"INDICES:\n{indices}\n")
print(f"COLUMNS:\n{columns}\n")
print(f"DATAPOINTS SIZE: {df_size}")
print(f"DIMENSIONS: ")
for dim in punjab_t2m_modified.dims:
    print(f"{dim}: {punjab_t2m_modified.sizes[dim]}")
# Out:
# INDICES:
# time
# latitude
# longitude
#
# COLUMNS:
# t2m
#
# DATAPOINTS SIZE: 1064340
# DIMENSIONS:
# time: 1460
# latitude: 27
# longitude: 27

# %% [markdown]
# ## Slicing out Karnatka Dataset

# %%
KARNATKA_MIN_LAT = 11.5
KARNATKA_MAX_LAT = 18.5
KARNATKA_MIN_LONG = 74.0
KARNATKA_MAX_LONG = 78.5

karnatka_t2m_modified = south_asia_t2m_modified.sel(latitude=slice(KARNATKA_MAX_LAT, KARNATKA_MIN_LAT), longitude=slice(KARNATKA_MIN_LONG, KARNATKA_MAX_LONG))

# %%
karnatka_t2m_modified
# Out:
# <xarray.Dataset> Size: 3MB
# Dimensions:    (time: 1460, latitude: 29, longitude: 19)
# Coordinates:
#   * time       (time) datetime64[ns] 12kB 2025-01-01 ... 2025-12-31T18:00:00
#   * latitude   (latitude) float64 232B 18.5 18.25 18.0 17.75 ... 12.0 11.75 11.5
#   * longitude  (longitude) float64 152B 74.0 74.25 74.5 ... 78.0 78.25 78.5
# Data variables:
#     t2m        (time, latitude, longitude) float32 3MB 292.2 292.8 ... 296.4
# Attributes:
#     GRIB_edition:            1
#     GRIB_centre:             ecmf
#     GRIB_centreDescription:  European Centre for Medium-Range Weather Forecasts
#     GRIB_subCentre:          0
#     Conventions:             CF-1.7
#     institution:             European Centre for Medium-Range Weather Forecasts
#     history:                 2026-08-09T16:04 GRIB to CDM+CF via cfgrib-0.9.1...

# %%
indices = "\n".join(karnatka_t2m_modified.dims)
columns = "\n".join(karnatka_t2m_modified.data_vars)
df_size = karnatka_t2m_modified['t2m'].size

print(f"INDICES:\n{indices}\n")
print(f"COLUMNS:\n{columns}\n")
print(f"DATAPOINTS SIZE: {df_size}")
print(f"DIMENSIONS: ")
for dim in karnatka_t2m_modified.dims:
    print(f"{dim}: {karnatka_t2m_modified.sizes[dim]}")
# Out:
# INDICES:
# time
# latitude
# longitude
#
# COLUMNS:
# t2m
#
# DATAPOINTS SIZE: 804460
# DIMENSIONS:
# time: 1460
# latitude: 29
# longitude: 19

# %% [markdown]
# ## Saving Processed Dataset

# %%
south_asia_t2m_modified.to_netcdf('./datasets/south_asia_t2m.nc')
punjab_t2m_modified.to_netcdf('./datasets/punjab_t2m.nc')
karnatka_t2m_modified.to_netcdf('./datasets/karnatka_t2m.nc')

# %% [markdown]
# ## Visualization

# %%
def visualize(ds:xarray.Dataset):
    ds = ds.copy()
    ds['t2m'] = ds['t2m'] - 273.15
    t_min = ds['t2m'].min().item()
    t_max = ds['t2m'].max().item()
    fig = px.imshow(
        ds['t2m'], 
        animation_frame='time', 
        x=ds['longitude'], 
        y=ds['latitude'],   
        color_continuous_scale='RdBu_r',
        title="t2m Heatmap over Time",
        height=1000,
        width=1000,
        range_color=[t_min, t_max],
        origin='lower'
    )

    return fig

# %%
fig = visualize(south_asia_t2m_modified)
fig.write_html("./outputs/south_asia_t2m_org.html")

# %%
fig = visualize(punjab_t2m_modified)
fig.write_html("./outputs/punjab_t2m_org.html")

# %%
fig = visualize(karnatka_t2m_modified)
fig.write_html("./outputs/karnatka_t2m_org.html")
